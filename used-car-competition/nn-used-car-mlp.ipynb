# %%
import sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score, validation_curve, learning_curve, ValidationCurveDisplay, LearningCurveDisplay
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, make_scorer
import matplotlib.pyplot as plt
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
rng=11

# %%
X_train = pd.read_parquet('data/X_pca.parquet')
X_test = pd.read_parquet('data/X_pca_test.parquet')

# %%
X_test.shape
# Out:
# (188533, 1)

# %%
y_train = pd.read_parquet('data/train.parquet')['price']
y_train.head()
# Out:
# 0     4200
# 1     4999
# 2    13900
# 3    45000
# 4    97500
# Name: price, dtype: int64

# %%
y = y_train.values.ravel()

# %%
X_train
# Out:
#                0
# 0       2.957834
# 1       1.557180
# 2       1.426272
# 3      -0.927851
# 4      -1.171073
# ...          ...
# 188528 -0.335460
# 188529 -0.745114
# 188530 -1.045326
# 188531 -1.040406
# 188532 -0.124609
#
# [188533 rows x 1 columns]

# %%
estimator = MLPRegressor(max_iter=1000, random_state=rng, early_stopping=True)
param_name = "hidden_layer_sizes"

# %%
hidden_layer_sizes = {
    'one_layer': [(120,), (150,)],
    'two_layer_refined': [(20, 25), (25, 30), (15, 30)],
    'two_layer_complex': [(50, 50), (80, 80)],
    'three_layer': [(20, 30, 20), (30, 40, 30)],
    'varying_depth': [(30, 30), (30, 30, 30), (30, 30, 30, 30)]
}

param_range = [item for sublist in hidden_layer_sizes.values() for item in sublist]
# param_range = [(x,) for x in np.arange(10, 110, 10)]
param_range_str = [str(x) for x in param_range]

hidden_train_scores, hidden_valid_scores = validation_curve(estimator, X_train, y_train, param_name=param_name, param_range=param_range, cv=5, scoring=mse_scorer,n_jobs=-1)
# Out:
# /Users/nikhilkapila/miniconda3/envs/kaggle/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
display = ValidationCurveDisplay(param_name=param_name, param_range=param_range_str,
                                 train_scores=hidden_train_scores, test_scores=hidden_valid_scores,
                                 score_name="mse")

param = { "line_kw" : {"marker":"o"}}
display.plot(**param)
plt.title(param_name + " - Wine Dataset ")
plt.xticks(param_range, labels=[f"{p:.1e}" for p in param_range])
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[16], line 6
#       1 display = ValidationCurveDisplay(param_name=param_name, param_range=param_range_str,
#       2                                  train_scores=hidden_train_scores, test_scores=hidden_valid_scores,
#       3                                  score_name="mse")
#       5 param = { "line_kw" : {"marker":"o"}}
# ----> 6 display.plot(**param)
#       7 plt.title(param_name + " - Wine Dataset ")
#       8 plt.xticks(param_range, labels=[f"{p:.1e}" for p in param_range])
#
# File ~/miniconda3/envs/kaggle/lib/python3.12/site-packages/sklearn/model_selection/_plot.py:659, in ValidationCurveDisplay.plot(self, ax, negate_score, score_name, score_type, std_display_style, line_kw, fill_between_kw, errorbar_kw)
#     598 def plot(
#     599     self,
#     600     ax=None,
#    (...)
#     608     errorbar_kw=None,
#     609 ):
#     610     """Plot visualization.
#     611
#     612     Parameters
#    (...)
#     657         Object that stores computed values.
#     658     """
# --> 659     self._plot_curve(
#     660         self.param_range,
#     661         ax=ax,
#     662         negate_score=negate_score,
#     663         score_name=score_name,
#     664         score_type=score_type,
#     665         std_display_style=std_display_style,
#     666         line_kw=line_kw,
#     667         fill_between_kw=fill_between_kw,
#     668         errorbar_kw=errorbar_kw,
#     669     )
#     670     self.ax_.set_xlabel(f"{self.param_name}")
#     671     return self
#
# File ~/miniconda3/envs/kaggle/lib/python3.12/site-packages/sklearn/model_selection/_plot.py:111, in _BaseCurveDisplay._plot_curve(self, x_data, ax, negate_score, score_name, score_type, std_display_style, line_kw, fill_between_kw, errorbar_kw)
#     106 ax.legend()
#     108 # We found that a ratio, smaller or bigger than 5, between the largest and
#     109 # smallest gap of the x values is a good indicator to choose between linear
#     110 # and log scale.
# --> 111 if _interval_max_min_ratio(x_data) > 5:
#     112     xscale = "symlog" if x_data.min() <= 0 else "log"
#     113 else:
#
# File ~/miniconda3/envs/kaggle/lib/python3.12/site-packages/sklearn/utils/_plotting.py:98, in _interval_max_min_ratio(data)
#      91 def _interval_max_min_ratio(data):
#      92     """Compute the ratio between the largest and smallest inter-point distances.
#      93
#      94     A value larger than 5 typically indicates that the parameter range would
#      95     better be displayed with a log scale while a linear scale would be more
#      96     suitable otherwise.
#      97     """
# ---> 98     diff = np.diff(np.sort(data))
#      99     return diff.max() / diff.min()
#
# File ~/miniconda3/envs/kaggle/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:1515, in diff(a, n, axis, prepend, append)
#    1513 op = not_equal if a.dtype == np.bool else subtract
#    1514 for _ in range(n):
# -> 1515     a = op(a[slice1], a[slice2])
#    1517 return a
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U16'), dtype('<U16')) -> None

# %%
mlp = MLPRegressor(hidden_layer_sizes=(120,), random_state=11, learning_rate_init=0.001, max_iter=1000, early_stopping=True)

# %%
mlp.fit(X_train, y)
# Out:
# MLPRegressor(early_stopping=True, hidden_layer_sizes=(120,), max_iter=1000,
#              random_state=11)

# %%
pd.DataFrame(X_test['0'])
# Out:
# 0         0.636300
# 1        -1.132939
# 2        -0.755051
# 3        -0.095265
# 4        -0.140224
#             ...
# 125685    0.343909
# 125686   -0.730859
# 125687    0.230795
# 125688    0.915052
# 125689    0.015877
# Name: 0, Length: 125690, dtype: float64

# %%
preds = mlp.predict(pd.DataFrame(X_test['0']))
# Out:
# /Users/nikhilkapila/miniconda3/envs/kaggle/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(

# %%
preds_df = pd.DataFrame(preds, columns=['price'])
preds_df
# Out:
#                price
# 0       14974.574473
# 1       75927.657522
# 2       62908.812139
# 3       40178.137210
# 4       41727.036141
# ...              ...
# 125685  25047.905234
# 125686  62075.370065
# 125687  28944.847148
# 125688   5371.126697
# 125689  36349.105385
#
# [125690 rows x 1 columns]

# %%
preds_df['id'] = X_test['id']

# %%
preds_df
# Out:
#                price      id
# 0       14974.574473  188533
# 1       75927.657522  188534
# 2       62908.812139  188535
# 3       40178.137210  188536
# 4       41727.036141  188537
# ...              ...     ...
# 125685  25047.905234  314218
# 125686  62075.370065  314219
# 125687  28944.847148  314220
# 125688   5371.126697  314221
# 125689  36349.105385  314222
#
# [125690 rows x 2 columns]

# %%
preds_df.to_csv('data/output.csv', index=False)
